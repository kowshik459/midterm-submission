# %%
pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\kopoa\anaconda\lib\site-packages (from stable-baselines3) (1.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\kopoa\anaconda\lib\site-packages (from stable-baselines3) (2.1.3)
# Collecting torch<3.0,>=2.3 (from stable-baselines3)
#   Downloading torch-2.10.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: cloudpickle in c:\users\kopoa\anaconda\lib\site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\kopoa\anaconda\lib\site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\kopoa\anaconda\lib\site-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\kopoa\anaconda\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\kopoa\anaconda\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\kopoa\anaconda\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kopoa\anaconda\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kopoa\anaconda\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kopoa\anaconda\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kopoa\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kopoa\anaconda\lib\site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kopoa\anaconda\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
# Downloading torch-2.10.0-cp313-cp313-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/113.8 MB 4.1 MB/s eta 0:00:28
#     --------------------------------------- 1.8/113.8 MB 4.9 MB/s eta 0:00:24
#     --------------------------------------- 2.4/113.8 MB 3.9 MB/s eta 0:00:29
#    - -------------------------------------- 3.4/113.8 MB 4.3 MB/s eta 0:00:26
#    - -------------------------------------- 3.4/113.8 MB 4.3 MB/s eta 0:00:26
#    - -------------------------------------- 4.2/113.8 MB 3.4 MB/s eta 0:00:32
#    - -------------------------------------- 5.2/113.8 MB 3.6 MB/s eta 0:00:30
#    -- ------------------------------------- 6.3/113.8 MB 3.8 MB/s eta 0:00:28
#    -- ------------------------------------- 7.9/113.8 MB 4.2 MB/s eta 0:00:26
#    --- ------------------------------------ 9.2/113.8 MB 4.4 MB/s eta 0:00:24
#    --- ------------------------------------ 10.7/113.8 MB 4.7 MB/s eta 0:00:22
#    ---- ----------------------------------- 11.8/113.8 MB 4.7 MB/s eta 0:00:22
#    ---- ----------------------------------- 13.4/113.8 MB 4.9 MB/s eta 0:00:21
#    ----- ---------------------------------- 14.7/113.8 MB 5.0 MB/s eta 0:00:20
#    ----- ---------------------------------- 16.0/113.8 MB 5.1 MB/s eta 0:00:20
#    ----- ---------------------------------- 17.0/113.8 MB 5.1 MB/s eta 0:00:19
#    ------ --------------------------------- 18.6/113.8 MB 5.2 MB/s eta 0:00:19
#    ------- -------------------------------- 19.9/113.8 MB 5.3 MB/s eta 0:00:18
#    ------- -------------------------------- 21.0/113.8 MB 5.3 MB/s eta 0:00:18
#    ------- -------------------------------- 22.5/113.8 MB 5.4 MB/s eta 0:00:17
#    -------- ------------------------------- 23.9/113.8 MB 5.4 MB/s eta 0:00:17
#    -------- ------------------------------- 24.9/113.8 MB 5.4 MB/s eta 0:00:17
#    --------- ------------------------------ 26.0/113.8 MB 5.4 MB/s eta 0:00:17
#    --------- ------------------------------ 26.7/113.8 MB 5.3 MB/s eta 0:00:17
#    --------- ------------------------------ 27.8/113.8 MB 5.3 MB/s eta 0:00:17
#    ---------- -----------------------------
8 MB/s eta 0:00:11
#    ---------------------- ----------------- 63.2/113.8 MB 4.8 MB/s eta 0:00:11
#    ---------------------- ----------------- 64.2/113.8 MB 4.8 MB/s eta 0:00:11
#    ----------------------- ---------------- 65.5/113.8 MB 4.8 MB/s eta 0:00:11
#    ----------------------- ---------------- 66.8/113.8 MB 4.8 MB/s eta 0:00:10
#    ------------------------ --------------- 68.4/113.8 MB 4.9 MB/s eta 0:00:10
#    ------------------------ --------------- 70.0/113.8 MB 4.9 MB/s eta 0:00:09
#    ------------------------- -------------- 71.3/113.8 MB 4.9 MB/s eta 0:00:09
#    ------------------------- -------------- 72.6/113.8 MB 4.9 MB/s eta 0:00:09
#    ------------------------- -------------- 73.9/113.8 MB 5.0 MB/s eta 0:00:09
#    -------------------------- ------------- 75.5/113.8 MB 5.0 MB/s eta 0:00:08
#    --------------------------- ------------ 76.8/113.8 MB 5.0 MB/s eta 0:00:08
#    --------------------------- ------------ 78.6/113.8 MB 5.1 MB/s eta 0:00:07
#    ---------------------------- ----------- 80.2/113.8 MB 5.1 MB/s eta 0:00:07
#    ---------------------------- ----------- 81.0/113.8 MB 5.1 MB/s eta 0:00:07
#    ---------------------------- ----------- 82.1/113.8 MB 5.1 MB/s eta 0:00:07
#    ----------------------------- ---------- 83.6/113.8 MB 5.1 MB/s eta 0:00:06
#    ----------------------------- ---------- 84.9/113.8 MB 5.1 MB/s eta 0:00:06
#    ------------------------------ --------- 86.0/113.8 MB 5.1 MB/s eta 0:00:06
#    ------------------------------ --------- 87.3/113.8 MB 5.1 MB/s eta 0:00:06
#    ------------------------------ --------- 88.1/113.8 MB 5.1 MB/s eta 0:00:06
#    ------------------------------ --------- 88.1/113.8 MB 5.1 MB/s eta 0:00:06
#    ------------------------------- -------- 88.6/113.8 MB 5.0 MB/s eta 0:00:06
#    ------------------------------- -------- 89.7/113.8 MB 5.0 MB/s eta 0:00:05
#    -------------------------------- ------- 91.2/113.8 MB 5.0 MB/s eta 0:00:05
#    -------------------------------- ------- 92.5/113.8 MB 5.0 MB/s eta 0:00:05
#    -------------------------------- ------- 93.6/113.8 MB 5.0 MB/s eta 0:00:05
#    -------------------------------- ------- 93.8/113.8 MB 5.0 MB/s eta 0:00:04
#    -------------------------------- ------- 93.8/113.8 MB 5.0 MB/s eta 0:00:04
#    --------------------------------- ------ 94.6/113.8 MB 4.9 MB/s eta 0:00:04
#    --------------------------------- ------ 95.7/113.8 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 97.3/113.8 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 98.3/113.8 MB 5.0 MB/s eta 0:00:04
#    ----------------------------------- ---- 99.6/113.8 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 101.2/113.8 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 102.2/113.8 MB 5.0 MB/s eta 0:00:03
#    ------------------------------------ --- 103.5/113.8 MB 5.0 MB/s eta 0:00:03
#    ------------------------------------ --- 105.1/113.8 MB 5.0 MB/s eta 0:00:02
#    ------------------------------------- -- 106.4/113.8 MB 5.0 MB/s eta 0:00:02
#    -------------------------------------- - 108.3/113.8 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 110.1/113.8 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 110.9/113.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  112.5/113.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: torch, stable-baselines3
#
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    -------------------- ------------------- 1/2 [stable-baselines3]
#    ---------------------------------------- 2/2 [stable-baselines3]
#
# Successfully installed stable-baselines3-2.7.1 torch-2.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from stable_baselines3 import PPO

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\kopoa\OneDrive\citadel\Week 3\day04_first_agent

# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

from day02_environment.trading_env import TradingEnv

# %%
env = TradingEnv(max_steps=100)

check_env(env, warn=True)
print("Environment check passed")
# Out:
# Environment check passed

# %%
model = PPO(
    policy="MlpPolicy",
    env=env,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=10_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -0.44    |
# | time/              |          |
# |    fps             | 812      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.372      |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008020635 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.332      |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009465171 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00846    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.00118     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.289      |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010260358 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.000497    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.253      |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011026114 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.00015     |
# -----------------------------------------

# %% [markdown]
# Day 4 Observations
# Day 4 Observation
# PPO training completed successfully without numerical instability. The learned policy converged to a conservative strategy that predominantly selects the Hold action.
#
# This behavior is consistent with the reward design, where transaction risk dominates expected profit due to noisy price dynamics.
#
# This confirms that the environment and reward function support stable learning.
